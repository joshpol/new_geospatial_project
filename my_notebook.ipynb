# %%
message = "hello world!"
print(message)
# Out:
# hello world!

# %%
import geopandas as gpd

# %%
data_path = "/Users/joshua/Library/CloudStorage/OneDrive-UniversityofChester/MSC Marine and Coastal Resource Management/Biodiversity Informatics/Hairy Dragonfly Variables.csv"

# %%
gdf = gpd.read_file(data_path)

# %%
gdf
# Out:
#                x            y Observed  Water.Vapor Precipitation  \
# 0    7.291666667       43.875        1   1.31280005          49.5
# 1          9.875  53.95833333        1  1.105000019            67
# 2          1.125  49.29166667        1  1.189599991            47
# 3         -3.875       43.125        1  1.108799934          74.5
# 4    22.20833333       40.625        1  1.358999968          32.5
# ..           ...          ...      ...          ...           ...
# 88        -3.125       58.625        1  0.996399999            63
# 89  -2.041666667  57.45833333        1  0.999800026            60
# 90   11.20833333       43.375        1  1.233800054          56.5
# 91        -5.125  39.29166667        1  1.233599901          26.5
# 92  -1.708333333  40.70833333        1  0.840600014          41.5
#
#     Temperature Elevation
# 0   13.45800018       565
# 1   5.306000233        25
# 2   8.236000061        37
# 3   6.454666615       774
# 4   10.33666611        23
# ...
